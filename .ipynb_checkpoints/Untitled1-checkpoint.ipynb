# %%
import pandas as pd
import os

caminho = r'C:\Users\Gabriel\Desktop\pythonImpressionador\Power-Bi_Python'
vendas_df = pd.read_csv(r'C:\Users\Gabriel\Desktop\pythonImpressionador\Power-Bi_Python\Contoso - Vendas - 2017.csv ', sep=';')
produtos_df = pd.read_csv(os.path.join(caminho, r'Contoso - Cadastro Produtos.csv'),sep=';')
lojas_df = pd.read_csv(os.path.join(caminho, r'Contoso - Lojas.csv'),sep=';')
clientes_df = pd.read_csv(os.path.join(caminho, r'Contoso - Clientes.csv'),sep=';')


#limpando apenas as colunas que eu quero
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja' , 'Nome da Loja']]

#Mesclando

vendas_df = vendas_df.merge(produtos_df , on='ID Produto')
vendas_df = vendas_df.merge(lojas_df , on='ID Loja')
vendas_df = vendas_df.merge(clientes_df , on='ID Cliente').rename(columns={'E-mail' : 'E-mail do Clientes'})
display(vendas_df)

dataset = vendas_df
tres_lojas_df = dataset[dataset['ID Loja'].isin([86, 306, 172])]
display(tres_lojas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import seaborn as sns

sns.set_theme(style="darkgrid")
fig, ax = plt.subplots(figsize=(15,5))
#Editando eixo
ax.xaxis.set_major_locator(plt.MaxNLocator(12))
ax.xaxis.set_major_formatter(DateFormatter('%m'))
#Plotando Grafico
sns.lineplot(x="Data da Venda", y="Quantidade Vendida", hue="Nome da Loja", data=dataset, ax=ax)

plt.show()
